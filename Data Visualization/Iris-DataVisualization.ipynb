# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
species = iris['Species']
species.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
id = iris['Id']
id.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id, dtype: int64

# %%
idS = iris.iloc[0:50, 0]
idVe = iris.iloc[51:100, 0]
idVi = iris.iloc[101:150, 0]

# %%
sepalLength = iris['SepalLengthCm']
sepalLS = iris.iloc[0:50, 1]
sepalLVe = iris.iloc[51:100, 1]
sepalLVi = iris.iloc[101:150, 1]
sepalLength.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: SepalLengthCm, dtype: float64

# %%
sepalLSentosa.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-054c3f2427e2> in <module>
# ----> 1 sepalLSentosa.head()
#
# NameError: name 'sepalLSentosa' is not defined

# %%
sepalWidth = iris['SepalWidthCm']
sepalWidth.head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: SepalWidthCm, dtype: float64

# %%
#sepalLength = iris['SepalLengthCm']
sepalWS = iris.iloc[0:50, 2]
sepalWVe = iris.iloc[51:100, 2]
sepalWVi = iris.iloc[101:150, 2]

# %%
petalLength = iris['PetalLengthCm']
petalLength.head()
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: PetalLengthCm, dtype: float64

# %%
petalLS  = iris.iloc[0:50, 3]
petalLVe = iris.iloc[51:100, 3]
petalLVi = iris.iloc[101:150, 3]

# %%
petalWidth = iris['PetalWidthCm']
petalWidth.head()
# Out:
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# Name: PetalWidthCm, dtype: float64

# %%
petalWS = iris.iloc[0:50, 4]
petalWVe = iris.iloc[51:100, 4]
petalWVi = iris.iloc[101:150, 4]

# %%
plt.scatter(id, sepalLength)
plt.xlabel("ID")
plt.ylabel("Sepal Length in cm")
plt.plot()
# Out:
# []

# %%
plt.scatter(idS, sepalLS, c = "#FF0000") #red
plt.scatter(idVe, sepalLVe, c = "#00FF00") #green
plt.scatter(idVi, sepalLVi, c = "#0000FF") #blue
plt.xlabel("ID")
plt.ylabel("Sepal Length in cm")
plt.plot()
# Out:
# []

# %%
plt.scatter(id, sepalWidth)
plt.xlabel("ID")
plt.ylabel("Sepal Width in cm")
# Out:
# Text(0, 0.5, 'Sepal Width in cm')

# %%
plt.scatter(idS, sepalWS, c = "#FF0000") #red
plt.scatter(idVe, sepalWVe, c = "#00FF00") #green
plt.scatter(idVi, sepalWVi, c = "#0000FF") #blue
plt.xlabel("ID")
plt.ylabel("Sepal Width in cm")
plt.plot()
# Out:
# []

# %%
plt.scatter(id, petalWidth)
plt.xlabel("ID")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(idS, petalWS, c = "#FF0000") #red
plt.scatter(idVe, petalWVe, c = "#00FF00") #green
plt.scatter(idVi, petalWVi, c = "#0000FF") #blue
plt.xlabel("ID")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(id, sepalWidth)
plt.xlabel("ID")
plt.ylabel("Sepal Width in cm")
plt.plot()
# Out:
# []

# %%
plt.scatter(idS, sepalWS, c = "#FF0000") #red
plt.scatter(idVe, sepalWVe, c = "#00FF00") #green
plt.scatter(idVi, sepalWVi, c = "#0000FF") #blue
plt.xlabel("ID")
plt.ylabel("Sepal Width in cm")
# Out:
# Text(0, 0.5, 'Sepal Width in cm')

# %%
plt.scatter(sepalWidth, petalWidth)
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(sepalWS, petalWS, c= "#FF0000") #red
plt.scatter(sepalWVe, petalWVe, c = "#00FF00") #green
plt.scatter(sepalWVi, petalWVi, c = "#0000FF") #blue
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(sepalLength, petalLength)
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(sepalLS, petalLS, c = "#ff0000")
plt.scatter(sepalLVe, petalLVe, c = "#00ff00")
plt.scatter(sepalLVi, petalLVi, c = "#0000ff")
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(sepalWidth, petalWidth)
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
# Out:
# Text(0, 0.5, 'Petal Width in cm')

# %%
plt.scatter(sepalWS, petalWS, c = "#ff0000")
plt.scatter(sepalWVe, petalWVe, c = "#00ff00")
plt.scatter(sepalWVi, petalWVi, c = "#0000ff")
plt.xlabel("Sepal Width in cm")
plt.ylabel("Petal Width in cm")
plt.plot()
# Out:
# []
